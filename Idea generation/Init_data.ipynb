# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv('7_days_High_Impact_Outages_20230116.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 24 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Region                                90 non-null     object
#  1   NSP                                   90 non-null     object
#  2   Start                                 90 non-null     object
#  3   Finish                                90 non-null     object
#  4   Network Asset                         90 non-null     object
#  5   Impact                                90 non-null     object
#  6   Recall                                90 non-null     object
#  7   Status                                90 non-null     object
#  8   Status and
# Market Notice             111 non-null    object
#  9   Project Work?                         0 non-null      float64
#  10  Unplanned?                            0 non-null      float64
# ...

# %%
df.head()
# Out:
#   Region          NSP                          Start  \
# 0    TAS  TasNetworks    24/01/2023 07:00\r\nTuesday
# 1    QLD    Powerlink  08/02/2023 07:00\r\nWednesday
# 2    TAS  TasNetworks  08/02/2023 07:00\r\nWednesday
# 3    QLD    Powerlink     10/02/2023 08:00\r\nFriday
# 4    QLD    Powerlink    21/02/2023 08:00\r\nTuesday
#
#                           Finish                         Network Asset  \
# 0    24/01/2023 14:30\r\nTuesday   Gordon - Chapel St No.1 220 kV Line
# 1  08/02/2023 17:00\r\nWednesday   Nebo - Strathmore (822) 275 kV Line
# 2  08/02/2023 14:30\r\nWednesday   Gordon - Chapel St No.2 220 kV Line
# 3     10/02/2023 16:00\r\nFriday   Broadsound - Nebo (834) 275 kV Line
# 4    21/02/2023 17:00\r\nTuesday  Nebo - Strathmore (8845) 275 kV Line
#
#                                                                                                                                                                                                         Impact  \
# ...
