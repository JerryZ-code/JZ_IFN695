# %%
import os
import time
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import re

# Define the download directory (Change this to your desired directory)
data_dir = 'aemo_data'  # Change this path if needed
os.makedirs(data_dir, exist_ok=True)  # Ensure the directory exists

# Base URL for the report page
base_url = "https://www.nemweb.com.au/REPORTS/CURRENT/HighImpactOutages/"

# Headers to mimic a browser request
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Date range for filtering files
start_year, start_month = 2021, 8  # Aug 2021
end_year, end_month = 2024, 8      # Aug 2024

# Skip these specific files
skip_files = [
    "7_days_High_Impact_Outages_20230116.csv",
    "7_days_High_Impact_Outages_22021128.csv"
]

# Regex pattern to extract dates from filenames
date_pattern = re.compile(r"High_Impact_Outages_(\d{4})(\d{2})(\d{2})\.csv")

# Fetch the webpage with all the file links
response = requests.get(base_url, headers=headers)
if response.status_code != 200:
    print(f"Failed to fetch webpage: {response.status_code}")
    exit()

# Parse the HTML content of the page
soup = BeautifulSoup(response.text, "html.parser")

# Find all CSV links on the page
for link in soup.find_all("a", href=True):
    file_name = link["href"]

    # Ensure it's a CSV file
    if not file_name.endswith(".csv"):
        continue

    # Skip the files in the skip list
    if file_name in skip_files:
        print(f"Skipping {file_name} (in skip list)")
        continue

    # Extract YYYYMMDD from the filename using regex
    match = date_pattern.search(file_name)
    if match:
        year, month, day = int(match.group(1)), int(match.group(2)), int(match.group(3))

        # Check if the file's date is within the specified range
        if (start_year < year < end_year) or (year == start_year and month >= start_month) or (year == end_year and month <= end_month):
            file_url = urljoin(base_url, file_name)
            
            # Use os.path.basename to get the filename without leading slashes
            file_name = os.path.basename(file_name)  # Ensure no leading slashes in filename
            file_path = os.path.join(data_dir, file_name)

            # Print debug to verify the correct file path
            print(f"Saving file to: {file_path}")

            # Skip download if the file already exists
            if os.path.exists(file_path):
                print(f"Skipping {file_name} - already exists")
                continue

            # Download the file
            try:
                print(f"Downloading: {file_name}")
                file_response = requests.get(file_url, headers=headers, stream=True)
                file_response.raise_for_status()  # Raise an error if the request fails

                # Save the file to the download directory
                with open(file_path, "wb") as file:
                    for chunk in file_response.iter_content(chunk_size=1024):
                        file.write(chunk)

            except requests.exceptions.RequestException as e:
                print(f"Failed to download {file_name}: {e}")

            time.sleep(1)  # Pause to avoid overwhelming the server

print("Filtered CSV files have been downloaded.")
# Out:
# Saving file to: aemo_data\7_days_High_Impact_Outages_20230116.csv
# Skipping 7_days_High_Impact_Outages_20230116.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20210830.csv
# Skipping High_Impact_Outages_20210830.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20210906.csv
# Skipping High_Impact_Outages_20210906.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20210913.csv
# Skipping High_Impact_Outages_20210913.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20210920.csv
# Skipping High_Impact_Outages_20210920.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20210927.csv
# Skipping High_Impact_Outages_20210927.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20211005.csv
# Skipping High_Impact_Outages_20211005.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20211011.csv
# Skipping High_Impact_Outages_20211011.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20211018.csv
# Skipping High_Impact_Outages_20211018.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20211025.csv
# Skipping High_Impact_Outages_20211025.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20211101.csv
# Skipping High_Impact_Outages_20211101.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20211108.csv
# Skipping High_Impact_Outages_20211108.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20211115.csv
# Skipping High_Impact_Outages_20211115.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20211122.csv
# Skipping High_Impact_Outages_20211122.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20211129.csv
# Skipping High_Impact_Outages_20211129.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20211206.csv
# Skipping High_Impact_Outages_20211206.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20211213.csv
# Skipping High_Impact_Outages_20211213.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20211220.csv
# Skipping High_Impact_Outages_20211220.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220104.csv
# Skipping High_Impact_Outages_20220104.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220110.csv
# Skipping High_Impact_Outages_20220110.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220117.csv
# Skipping High_Impact_Outages_20220117.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220124.csv
# Skipping High_Impact_Outages_20220124.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220131.csv
# Skipping High_Impact_Outages_20220131.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220207.csv
# Skipping High_Impact_Outages_20220207.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220214.csv
# Skipping High_Impact_Outages_20220214.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220221.csv
# Skipping High_Impact_Outages_20220221.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220307.csv
# Skipping High_Impact_Outages_20220307.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220314.csv
# Skipping High_Impact_Outages_20220314.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220321.csv
# Skipping High_Impact_Outages_20220321.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220328.csv
# Skipping High_Impact_Outages_20220328.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220404.csv
# Skipping High_Impact_Outages_20220404.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220411.csv
# Skipping High_Impact_Outages_20220411.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220419.csv
# Skipping High_Impact_Outages_20220419.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220426.csv
# Skipping High_Impact_Outages_20220426.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220502.csv
# Skipping High_Impact_Outages_20220502.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220509.csv
# Skipping High_Impact_Outages_20220509.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220516.csv
# Skipping High_Impact_Outages_20220516.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220523.csv
# Skipping High_Impact_Outages_20220523.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220530.csv
# Skipping High_Impact_Outages_20220530.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220606.csv
# Skipping High_Impact_Outages_20220606.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220614.csv
# Skipping High_Impact_Outages_20220614.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220620.csv
# Skipping High_Impact_Outages_20220620.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220627.csv
# Skipping High_Impact_Outages_20220627.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220704.csv
# Skipping High_Impact_Outages_20220704.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220711.csv
# Skipping High_Impact_Outages_20220711.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220718.csv
# Skipping High_Impact_Outages_20220718.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220725.csv
# Skipping High_Impact_Outages_20220725.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220801.csv
# Skipping High_Impact_Outages_20220801.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220815.csv
# Skipping High_Impact_Outages_20220815.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220822.csv
# Skipping High_Impact_Outages_20220822.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220829.csv
# Skipping High_Impact_Outages_20220829.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220905.csv
# Skipping High_Impact_Outages_20220905.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220912.csv
# Skipping High_Impact_Outages_20220912.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220919.csv
# Skipping High_Impact_Outages_20220919.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20220926.csv
# Skipping High_Impact_Outages_20220926.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20221004.csv
# Skipping High_Impact_Outages_20221004.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20221010.csv
# Skipping High_Impact_Outages_20221010.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20221017.csv
# Skipping High_Impact_Outages_20221017.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20221024.csv
# Skipping High_Impact_Outages_20221024.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20221031.csv
# Skipping High_Impact_Outages_20221031.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20221107.csv
# Skipping High_Impact_Outages_20221107.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20221114.csv
# Skipping High_Impact_Outages_20221114.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20221121.csv
# Skipping High_Impact_Outages_20221121.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20221212.csv
# Skipping High_Impact_Outages_20221212.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20221219.csv
# Skipping High_Impact_Outages_20221219.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230109.csv
# Skipping High_Impact_Outages_20230109.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230116.csv
# Skipping High_Impact_Outages_20230116.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230123.csv
# Skipping High_Impact_Outages_20230123.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230130.csv
# Skipping High_Impact_Outages_20230130.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230206.csv
# Skipping High_Impact_Outages_20230206.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230213.csv
# Skipping High_Impact_Outages_20230213.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230220.csv
# Skipping High_Impact_Outages_20230220.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230227.csv
# Skipping High_Impact_Outages_20230227.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230304.csv
# Skipping High_Impact_Outages_20230304.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230306.csv
# Skipping High_Impact_Outages_20230306.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230314.csv
# Skipping High_Impact_Outages_20230314.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230327.csv
# Skipping High_Impact_Outages_20230327.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230411.csv
# Skipping High_Impact_Outages_20230411.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230424.csv
# Skipping High_Impact_Outages_20230424.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230501.csv
# Skipping High_Impact_Outages_20230501.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230508.csv
# Skipping High_Impact_Outages_20230508.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230515.csv
# Skipping High_Impact_Outages_20230515.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230522.csv
# Skipping High_Impact_Outages_20230522.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230529.csv
# Skipping High_Impact_Outages_20230529.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230605.csv
# Skipping High_Impact_Outages_20230605.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230613.csv
# Skipping High_Impact_Outages_20230613.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230619.csv
# Skipping High_Impact_Outages_20230619.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230626.csv
# Skipping High_Impact_Outages_20230626.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230703.csv
# Skipping High_Impact_Outages_20230703.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230710.csv
# Skipping High_Impact_Outages_20230710.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230717.csv
# Skipping High_Impact_Outages_20230717.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230724.csv
# Skipping High_Impact_Outages_20230724.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230731.csv
# Skipping High_Impact_Outages_20230731.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230807.csv
# Skipping High_Impact_Outages_20230807.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230814.csv
# Skipping High_Impact_Outages_20230814.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230828.csv
# Skipping High_Impact_Outages_20230828.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230904.csv
# Skipping High_Impact_Outages_20230904.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230911.csv
# Skipping High_Impact_Outages_20230911.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20230918.csv
# Skipping High_Impact_Outages_20230918.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20231003.csv
# Skipping High_Impact_Outages_20231003.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20231009.csv
# Skipping High_Impact_Outages_20231009.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20231016.csv
# Skipping High_Impact_Outages_20231016.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20231023.csv
# Skipping High_Impact_Outages_20231023.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20231030.csv
# Skipping High_Impact_Outages_20231030.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20231106.csv
# Skipping High_Impact_Outages_20231106.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20231113.csv
# Skipping High_Impact_Outages_20231113.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20231120.csv
# Skipping High_Impact_Outages_20231120.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20231127.csv
# Skipping High_Impact_Outages_20231127.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20231204.csv
# Skipping High_Impact_Outages_20231204.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20231211.csv
# Skipping High_Impact_Outages_20231211.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20231218.csv
# Skipping High_Impact_Outages_20231218.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240102.csv
# Skipping High_Impact_Outages_20240102.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240108.csv
# Skipping High_Impact_Outages_20240108.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240115.csv
# Skipping High_Impact_Outages_20240115.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240122.csv
# Skipping High_Impact_Outages_20240122.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240129.csv
# Skipping High_Impact_Outages_20240129.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240205.csv
# Skipping High_Impact_Outages_20240205.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240212.csv
# Skipping High_Impact_Outages_20240212.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240219.csv
# Skipping High_Impact_Outages_20240219.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240226.csv
# Skipping High_Impact_Outages_20240226.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240304.csv
# Skipping High_Impact_Outages_20240304.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240312.csv
# Skipping High_Impact_Outages_20240312.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240318.csv
# Skipping High_Impact_Outages_20240318.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240325.csv
# Skipping High_Impact_Outages_20240325.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240402.csv
# Skipping High_Impact_Outages_20240402.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240408.csv
# Skipping High_Impact_Outages_20240408.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240415.csv
# Skipping High_Impact_Outages_20240415.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240422.csv
# Skipping High_Impact_Outages_20240422.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240429.csv
# Skipping High_Impact_Outages_20240429.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240506.csv
# Skipping High_Impact_Outages_20240506.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240513.csv
# Skipping High_Impact_Outages_20240513.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240520.csv
# Skipping High_Impact_Outages_20240520.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240527.csv
# Skipping High_Impact_Outages_20240527.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240603.csv
# Skipping High_Impact_Outages_20240603.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240611.csv
# Skipping High_Impact_Outages_20240611.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240617.csv
# Skipping High_Impact_Outages_20240617.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240624.csv
# Skipping High_Impact_Outages_20240624.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240701.csv
# Skipping High_Impact_Outages_20240701.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240708.csv
# Skipping High_Impact_Outages_20240708.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240715.csv
# Skipping High_Impact_Outages_20240715.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240729.csv
# Skipping High_Impact_Outages_20240729.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240805.csv
# Skipping High_Impact_Outages_20240805.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240812.csv
# Skipping High_Impact_Outages_20240812.csv - already exists
# Saving file to: aemo_data\High_Impact_Outages_20240826.csv
# Skipping High_Impact_Outages_20240826.csv - already exists
# Filtered CSV files have been downloaded.
