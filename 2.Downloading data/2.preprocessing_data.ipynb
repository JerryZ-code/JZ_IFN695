# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)

import os, glob, re

# %%
# Define a function to pre-process the files
def process_file(file_path):    
    def read_csv_with_fallback(file_path):
        encodings = ['utf-8', 'utf-8-sig', 'latin1', 'cp1252']
        for enc in encodings:
            try:
                df = pd.read_csv(file_path, delimiter=",", encoding=enc)
                print(f"Successfully read {file_path} with encoding: {enc}")
                return df
            except UnicodeDecodeError:
                print(f"Failed with encoding: {enc}")
                continue
        raise UnicodeDecodeError(f"Could not decode {file_path} with tried encodings.") 
    df = read_csv_with_fallback(file_path)  

    df.columns = df.columns.str.strip()

    # remove columns which have the 'Unnamed:' 
    df = df.loc[:, ~df.columns.str.startswith('Unnamed:')]
    
    # add a column to keep track of the csv file in which each entry came from
    base_name = os.path.basename(file_path)
    date_match = re.search(r'(\d{8})', base_name)
    if date_match:
        file_date = pd.to_datetime(date_match.group(1), format='%Y%m%d').date()
    else:
        file_date = None  # fallback if no date in filename
    df["file_name"] = file_date

    # drop the 'Vs Old' column, it has no meaning
    if 'Vs Old' in df.columns:
        df.drop(columns=['Vs Old'], inplace=True)

    # certain columns have \n and \r, so they are removed
    df = df.replace({r"\r|\n": " "}, regex=True)
    df.columns = df.columns.str.replace(r'[\r\n]', ' ', regex=True).str.replace(r'\s+', ' ', regex=True).str.strip()

    # pre-processing on the columns
    # extract information from the 'start' and 'finish' columns and separate into separate columns
    df['Start'] = df['Start'].replace({r'\r|\n': ' '}, regex=True)
    df['Finish'] = df['Finish'].replace({r'\r|\n': ' '}, regex=True)
    df['Start'] = pd.to_datetime(df['Start'], dayfirst=True, format='%d/%m/%Y %H:%M %A', errors='coerce')
    df['Finish'] = pd.to_datetime(df['Finish'], dayfirst=True, format='%d/%m/%Y %H:%M %A', errors='coerce')

    # extract information from 'recall'
    pattern = r"Day:\s*(\d+)\s*hr?s?(?:-Night:\s*(\d+)\s*hr?s?)?"
    df[["Recall_Day_Hours", "Recall_Night_Hours"]] = df["Recall"].str.extract(pattern)
    df["Recall_Day_Hours"] = pd.to_numeric(df["Recall_Day_Hours"], errors="coerce")
    df['Recall_Day_Hours'] = df['Recall_Day_Hours'].fillna(0)
    df["Recall_Night_Hours"] = pd.to_numeric(df["Recall_Night_Hours"], errors="coerce")
    df['Recall_Night_Hours'] = df['Recall_Night_Hours'].fillna(0)






    # extract information for 'Impact region, reason and duration'
    # this column only appears as of 28/03/2022
    # Default: start with Impact_Region = Region

    # Define a list of known region codes
    valid_regions = ['NSW', 'QLD', 'VIC', 'SA', 'TAS']
    region_pattern = r'\b(?:' + '|'.join(valid_regions) + r')\b\s*'

    source_col = None

    if "Impact Region, Reason and Duration" in df.columns:
        source_col = "Impact Region, Reason and Duration"
    elif "Reason and Duration" in df.columns:
        source_col = "Reason and Duration"

    if source_col:
        # Extract Reason and Duration
        pattern = r"([a-zA-Z\s]+?)\s+([\d.]+)\s*(Days?|Hours?|Minutes?)"
        extracted = df[source_col].str.extract(pattern)
        extracted.columns = ['Reason', 'Value', 'Unit']

        # Clean up Reason, Value, and Unit
        extracted["Reason"] = extracted["Reason"].str.strip()
        
        extracted["Value"] = pd.to_numeric(extracted["Value"], errors='coerce')
        df["Reason"] = extracted["Reason"]
        df['Reason'] = df['Reason'].str.replace(region_pattern, '', regex=True).str.strip()

        df["Value"] = extracted["Value"]
        df["Unit"] = extracted["Unit"]

        # Calculate Duration in Hours (based on 'Duration' column if you prefer that)
        if "Duration" in df.columns:
            duration_pattern = r"([\d\.]+)\s*(Days?|Hours?|Minutes?)"
            dur_extracted = df["Duration"].str.extract(duration_pattern)
            dur_extracted.columns = ["Value", "Unit"]
            dur_extracted["Value"] = pd.to_numeric(dur_extracted["Value"], errors="coerce")
            df["Duration_Hours"] = dur_extracted.apply(
                lambda row: row["Value"] * 24 if pd.notnull(row["Unit"]) and "Day" in row["Unit"]
                else row["Value"] if pd.notnull(row["Unit"]) and "Hour" in row["Unit"]
                else row["Value"] / 60 if pd.notnull(row["Unit"]) and "Minute" in row["Unit"]
                else None, axis=1)
        else:
            df["Duration_Hours"] = df.apply(
                lambda row: row["Value"] * 24 if pd.notnull(row["Unit"]) and "Day" in row["Unit"]
                else row["Value"] if pd.notnull(row["Unit"]) and "Hour" in row["Unit"]
                else row["Value"] / 60 if pd.notnull(row["Unit"]) and "Minute" in row["Unit"]
                else None, axis=1)

        df["Duration_Hours"] = df["Duration_Hours"].round(2)

        # Extract Impact_Region from known state codes
        def extract_regions(text):
            return " / ".join(re.findall(r"\b(?:NSW|QLD|VIC|SA|TAS)\b", str(text)))

        df["Impact_Region"] = df[source_col].apply(extract_regions)
        df.loc[df["Impact_Region"] == "", "Impact_Region"] = df["Region"]








    # split information from 'status'
    df[["Status_Description", "Status_Code"]] = df["Status"].str.split(" - ", expand=True)
    # Split information from 'status and market notice'
    df[['Status_Description_Market', 'Market_Notice_Code']] = df['Status and Market Notice'].str.split(" - ", n=1, expand=True)
    
    # Clean the column by removing "MN: " and "Issued on: " parts and keeping only the codes
    df["Market_Notice_Code"] = df["Market_Notice_Code"].str.replace(r"^(STLTP|MTLTP|RESUBMIT|PTP|PDLTP|PTR|UTP)\s*(?:MN: \d+ - Issued on:.*)?", r"\1", regex=True)


    # List of boolean columns
    bool_cols = ['Project Work?', 'Unplanned?', 'Generator Aware?', 'DNSP Aware?', 'Inter-Regional']
    # Replace 'T' with 1 and NaN with 0
    df[bool_cols] = df[bool_cols].apply(lambda col: col.map(lambda x: 1 if x == 'T' else 0))

    # drop non-needed columns now only if they're in the list
    cols_to_drop = ['Status', 'Status and Market Notice', 'Duration', 'Value', 'Unit',
                    'Reason and Duration', 'Recall']
    df.drop(columns=[col for col in cols_to_drop if col in df.columns], inplace=True)

    # re-order columns 
    # cols = list(df.columns) 
    new_col_order = ['Region', 'NSP', 
                    'Start', 'Finish', # Start and Finish information
                    'Network Asset', # identifying information
                    'Recall_Day_Hours', 'Recall_Night_Hours', # recall information
                    'Project Work?', 'Unplanned?', 'DNSP Aware?', 'Generator Aware?', 'Inter-Regional', # boolean terms
                    'Status_Description', 'Status_Code', 'Status_Description_Market', 'Market_Notice_Code', # status information
                    'Impact_Region', 'Reason', 'Duration_Hours', # reason and duration information
                    'Impact', 'file_name']
    new_col_order = list(dict.fromkeys(new_col_order))
    df = df[new_col_order]

    # remove rows where 'Region' is empty
    df = df[~df['Region'].str.startswith("The following fields of data are submitted by NSPs to AEMO.", na=False)]
    df = df.dropna(subset=['Region'])

    return df

# %%
# List of CSV files to process
csv_files = glob.glob("aemo_data/*.csv")

# List to store processed dataframes
processed_dfs = []

# Loop through each file, apply the processing function and collect the results
for file in csv_files:
    processed_df = process_file(file)
    processed_dfs.append(processed_df)

# there is an error with 20230109 and 20230314
# Out:
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20210830.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20210906.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20210913.csv with encoding: utf-8
# Successfully read aemo_data\High_Impact_Outages_20210920.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20210927.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20211005.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20211011.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20211018.csv with encoding: utf-8
# Successfully read aemo_data\High_Impact_Outages_20211025.csv with encoding: utf-8
# Successfully read aemo_data\High_Impact_Outages_20211101.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20211108.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20211115.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20211122.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20211129.csv with encoding: utf-8
# Successfully read aemo_data\High_Impact_Outages_20211206.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20211213.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20211220.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20220104.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20220110.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20220117.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20220124.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20220131.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20220207.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20220214.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20220221.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20220307.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20220314.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20220321.csv with encoding: utf-8
# Successfully read aemo_data\High_Impact_Outages_20220328.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20220404.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20220411.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20220419.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20220426.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20220502.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20220509.csv with encoding: utf-8
# Successfully read aemo_data\High_Impact_Outages_20220516.csv with encoding: utf-8
# Successfully read aemo_data\High_Impact_Outages_20220523.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20220530.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20220606.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20220614.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20220620.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20220627.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20220704.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20220711.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20220718.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20220725.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20220801.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20220815.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20220822.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20220829.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20220905.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20220912.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20220919.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20220926.csv with encoding: utf-8
# Successfully read aemo_data\High_Impact_Outages_20221004.csv with encoding: utf-8
# Successfully read aemo_data\High_Impact_Outages_20221010.csv with encoding: utf-8
# Successfully read aemo_data\High_Impact_Outages_20221017.csv with encoding: utf-8
# Successfully read aemo_data\High_Impact_Outages_20221024.csv with encoding: utf-8
# Successfully read aemo_data\High_Impact_Outages_20221031.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20221107.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20221114.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20221121.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20221212.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20221219.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20230109.csv with encoding: utf-8
# Successfully read aemo_data\High_Impact_Outages_20230116.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20230123.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20230130.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20230206.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20230213.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20230220.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20230227.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20230304.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20230306.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20230314.csv with encoding: utf-8
# Successfully read aemo_data\High_Impact_Outages_20230327.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20230411.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20230424.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20230501.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20230508.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20230515.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20230522.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20230529.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20230605.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20230613.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20230619.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20230626.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20230703.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20230710.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20230717.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20230724.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20230731.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20230807.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20230814.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20230828.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20230904.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20230911.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20230918.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20231003.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20231009.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20231016.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20231023.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20231030.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20231106.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20231113.csv with encoding: utf-8
# Successfully read aemo_data\High_Impact_Outages_20231120.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20231127.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20231204.csv with encoding: utf-8
# Successfully read aemo_data\High_Impact_Outages_20231211.csv with encoding: utf-8
# Successfully read aemo_data\High_Impact_Outages_20231218.csv with encoding: utf-8
# Successfully read aemo_data\High_Impact_Outages_20240102.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20240108.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20240115.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20240122.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20240129.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20240205.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20240212.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20240219.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20240226.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20240304.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20240312.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20240318.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20240325.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20240402.csv with encoding: utf-8
# Successfully read aemo_data\High_Impact_Outages_20240408.csv with encoding: utf-8
# Successfully read aemo_data\High_Impact_Outages_20240415.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20240422.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20240429.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20240506.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20240513.csv with encoding: utf-8
# Successfully read aemo_data\High_Impact_Outages_20240520.csv with encoding: utf-8
# Successfully read aemo_data\High_Impact_Outages_20240527.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20240603.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20240611.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20240617.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20240624.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20240701.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20240708.csv with encoding: latin1
# Successfully read aemo_data\High_Impact_Outages_20240715.csv with encoding: utf-8
# Successfully read aemo_data\High_Impact_Outages_20240729.csv with encoding: utf-8
# Successfully read aemo_data\High_Impact_Outages_20240805.csv with encoding: utf-8
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20240812.csv with encoding: latin1
# Failed with encoding: utf-8
# Failed with encoding: utf-8-sig
# Successfully read aemo_data\High_Impact_Outages_20240826.csv with encoding: latin1

# %%
# concatenate all dataframes and export to csv
full_df = pd.concat(processed_dfs, ignore_index=True)
full_df.info()
full_df.to_csv("processed_high_impact_outages.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18714 entries, 0 to 18713
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Region                     18714 non-null  object
#  1   NSP                        18714 non-null  object
#  2   Start                      18504 non-null  datetime64[ns]
#  3   Finish                     18504 non-null  datetime64[ns]
#  4   Network Asset              18714 non-null  object
#  5   Recall_Day_Hours           18714 non-null  float64
#  6   Recall_Night_Hours         18714 non-null  float64
#  7   Project Work?              18714 non-null  int64
#  8   Unplanned?                 18714 non-null  int64
#  9   DNSP Aware?                18714 non-null  int64
#  10  Generator Aware?           18714 non-null  int64
#  11  Inter-Regional             18714 non-null  int64
#  12  Status_Description         18707 non-null  object
#  13  Status_Code                17963 non-null  object
#  14  Status_Description_Market  18714 non-null  object
#  15  Market_Notice_Code         17971 non-null  object
#  16  Impact_Region              18714 non-null  object
#  17  Reason                     18714 non-null  object
#  18  Duration_Hours             18705 non-null  float64
#  19  Impact                     18714 non-null  object
#  20  file_name                  18714 non-null  object
# dtypes: datetime64[ns](2), float64(3), int64(5), object(11)
# memory usage: 3.0+ MB

# %%
for col in full_df.columns:
    print(full_df[col].value_counts())
    print('')
# Out:
# Region
# VIC         10099
# QLD          3932
# SA           2541
# NSW          1122
# TAS          1019
# VIC/ TAS        1
# Name: count, dtype: int64
#
# NSP
# AusNet         9991
# Powerlink      3932
# ElectraNet     2541
# Transgrid      1122
# TasNetworks    1019
# TOA             109
# Name: count, dtype: int64
#
# Start
# 2025-04-23 08:00:00    229
# 2025-09-02 08:00:00    111
# 2023-12-31 06:00:00     96
# 2024-06-04 06:00:00     93
# 2024-10-09 07:00:00     86
#                       ...
# 2022-11-12 04:01:00      1
# 2022-11-13 05:00:00      1
# 2022-11-12 05:00:00      1
# 2022-11-11 05:00:00      1
# 2025-06-17 08:00:00      1
# Name: count, Length: 1597, dtype: int64
#
# Finish
# 2025-09-15 17:00:00    170
# 2025-05-09 17:00:00    112
# 2023-12-31 16:00:00     96
# 2024-06-04 18:00:00     93
# 2024-10-21 17:00:00     88
#                       ...
# 2022-07-11 10:15:00      1
# 2022-07-12 11:30:00      1
# 2022-06-29 17:00:00      1
# 2024-07-21 17:30:00      1
# 2025-06-27 17:00:00      1
# Name: count, Length: 1614, dtype: int64
#
# Network Asset
# Moorabool - Mortlake 500 kV Line           1842
# Moorabool - Haunted Gully 500 kV line       706
# Stanwell - Broadsound (856) 275 kV Line     612
# Strathmore - Ross (8858) 275 kV Line        591
# Heywood - Tarrone 500 kV Line               566
#                                            ...
# Darlington Point A 330kV BUS                  2
# Buronga B2 220kV BUS                          2
# Heywood 500 kV CB 210                         2
# Bouldercmb - Nebo (821) 275kV Line            1
# MooraboolÐSydenham No.2 500 kV Line           1
# Name: count, Length: 120, dtype: int64
#
# Recall_Day_Hours
# 2.0      5483
# 4.0      2705
# 3.0      2134
# 6.0      2045
# 0.0      1965
# 1.0       740
# 60.0      712
# 48.0      578
# 72.0      539
# 8.0       445
# 120.0     410
# 159.0     327
# 5.0       207
# 24.0      182
# 12.0      170
# 16.0       57
# 18.0        6
# 14.0        4
# 10.0        4
# 7.0         1
# Name: count, dtype: int64
#
# Recall_Night_Hours
# 0.0      14765
# 12.0      1766
# 48.0       568
# 8.0        317
# 159.0      303
# 4.0        175
# 6.0        171
# 2.0        140
# 120.0      126
# 24.0       124
# 1.0         63
# 16.0        43
# 5.0         42
# 3.0         35
# 7.0         22
# 9.0         16
# 84.0        14
# 60.0         8
# 18.0         7
# 72.0         4
# 14.0         4
# 10.0         1
# Name: count, dtype: int64
#
# Project Work?
# 0    18225
# 1      489
# Name: count, dtype: int64
#
# Unplanned?
# 0    18708
# 1        6
# Name: count, dtype: int64
#
# DNSP Aware?
# 0    16178
# 1     2536
# Name: count, dtype: int64
#
# Generator Aware?
# 0    15155
# 1     3559
# Name: count, dtype: int64
#
# Inter-Regional
# 0    15604
# 1     3110
# Name: count, dtype: int64
#
# Status_Description
# Planned               17849
# Withdrawn               712
# In Progress             109
# Withdraw Requested       37
# Name: count, dtype: int64
#
# Status_Code
# SUBMIT      15689
# MTLTP        1557
# RESUBMIT      482
# PTP           105
# STLTP         101
# PDLTP          20
# UTP             5
# PTR             4
# Name: count, dtype: int64
#
# Status_Description_Market
# Planned                   17855
# Withdrawn                   704
# In Progress                 110
# Withdraw Requested           37
# Withdrawn    MN: 91693        3
# Withdrawn                     3
# UTP                           2
# Name: count, dtype: int64
#
# Market_Notice_Code
# SUBMIT                       15690
# MTLTP                         1562
# RESUBMIT                       481
# PTP                            106
# STLTP                          102
# PDLTP                           20
# PTR                              4
# Issued on: Thu 14/10/2021        3
# UTP                              3
# Name: count, dtype: int64
#
# Impact_Region
# VIC               6194
# QLD               3930
# VIC / SA          3810
# SA                2106
# TAS               1019
# NSW / VIC          826
# NSW                422
# NSW / QLD          325
# NSW / VIC / SA      69
# VIC / TAS           12
# VIC/ TAS             1
# Name: count, dtype: int64
#
# Reason
# Maintenance        14871
# Commissioning       3840
# Voltage Control        3
# Name: count, dtype: int64
#
# Duration_Hours
# 12.0     3741
# 10.0     3177
# 9.0      1337
# 153.6    1314
# 8.0       486
#          ...
# 45.6        1
# 10.9        1
# 9.4         1
# 8.9         1
# 8.7         1
# Name: count, Length: 171, dtype: int64
#
# Impact
# A credible contingency event during this planned outage could cause  synchronous separation of the South Australia region from the rest of  the NEM.  During this planned outage:   Power transfer will be restricted across the Victoria - South Australia interconnector (Heywood interconnector).   Post contingent FCAS will be sourced within SA following Separation event.                                                                                                                                       1971
# This is a high impact outage because the recall time is greater than 30 minutes.  A credible contingency event during this planned outage may require market intervention through issuing of directions.                                                                                                                                                                                                                                                                                                                  1931
# A credible contingency event during this planned outage could cause  synchronous separation of the South Australia region from the rest of  the NEM.  During this planned outage:  • Power transfer will be restricted across the Victoria - South Australia interconnector (Heywood interconnector).  • Post contingent FCAS will be sourced within SA following Separation event.                                                                                                                                       1766
# A credible contingency event during this planned outage may require market intervention through issuing of directions                                                                                                                                                                                                                                                                                                                                                                                                     1083
# This is a high impact outage because the recall time is greater than 30 minutes.  A credible contingency event during this planned outage may require market intervention through issuing of directions.                                                                                                                                                                                                                                                                                                                   888
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# <<NEW since the last notification>>  A credible contingency event during this planned outage could cause:    Synchronous separation of the Queensland region from the rest of the NEM    Large reduction in generation in NSW if exporting.                                                                                                                                                                                                                                                                                1
# <<UPDATED since the last notification>>  This is a high-impact outage only if the forecast temperature at Red Cliffs is greater than 30 °C  This outage offloads the Buronga to Darlington Point X5 220 kV line and restricts power transfer    Between Victoria and New South Wales.   Between South Australia and Victoria on Murraylink  A credible contingency event during this planned outage may require:    Load shedding in the Victorian outer grid   Market intervention through issuing of directions.       1
# This is a high-impact outage only if the forecast temperature at Red Cliffs is greater than 30 °C  This bus outage offloads Red Cliffs - Kiamal 220kV line, and Red Cliffs capacitor banks will be unavailable for automatic switching. A credible contingency event during this planned outage may require:  • Load shedding in the Victorian outer grid • Market intervention through issuing of directions.                                                                                                               1
# This is a high-impact outage only if the forecast temperature at Red Cliffs is greater than 30 °C During this planned outage power transfer will be restricted • Between Victoria and New South Wales. • Between South Australia and Victoria on Murraylink A credible contingency event during this planned outage may require: • Load shedding in the Victorian outer grid • Market intervention through issuing of directions.                                                                                            1
# <<NEW since the last notification>>  This bus outage offloads Red Cliffs - Wemen 220kV line, and Red Cliffs capacitor banks will be unavailable for automatic switching.  A credible contingency event during this planned outage may require:    Load shedding in the Victorian outer grid   Market intervention through issuing of directions.                                                                                                                                                                           1
# Name: count, Length: 219, dtype: int64
#
# file_name
# 2024-04-29    307
# 2024-04-22    290
# 2024-04-08    277
# 2024-04-15    270
# 2024-05-06    265
#              ...
# 2021-10-25     62
# 2021-10-11     61
# 2021-10-18     57
# 2021-11-08     55
# 2021-11-01     55
# Name: count, Length: 143, dtype: int64

# %%
# Inspect rows where 'Region' is null
null_region_rows = full_df[full_df['Duration_Hours'].isnull()]

# Display the rows with null values in the 'Region' column
print(null_region_rows)
# Out:
#       Region          NSP               Start              Finish  \
# 1005     TAS  TasNetworks 2022-01-11 07:00:00 2022-01-11 15:00:00
# 6824     QLD    Powerlink 2023-03-29 07:00:00 2023-03-29 15:00:00
# 9039     QLD    Powerlink 2023-09-04 07:00:00 2023-10-11 17:00:00
# 10109     SA   ElectraNet 2023-11-01 17:30:00 2023-11-02 05:30:00
# 10110     SA   ElectraNet 2023-11-02 17:30:00 2023-11-03 05:30:00
# 10246     SA   ElectraNet 2023-11-01 17:30:00 2023-11-02 05:30:00
# 10249     SA   ElectraNet 2023-11-02 17:30:00 2023-11-03 05:30:00
# 10376     SA   ElectraNet 2023-11-01 17:30:00 2023-11-02 05:30:00
# 10379     SA   ElectraNet 2023-11-02 17:30:00 2023-11-03 05:30:00
#
#                                   Network Asset  Recall_Day_Hours  \
# 1005        Gordon - Chapel St No.2 220 kV Line               2.0
# 6824        Ross No.3 288/138/19 kV Transformer               8.0
# 9039         Bouldercmb - Nebo (821) 275kV Line               0.0
# 10109  Tailem Bend - Tungkillo No.2 275 kV Line               0.0
# 10110  Tailem Bend - Tungkillo No.1 275 kV Line               0.0
# 10246  Tailem Bend - Tungkillo No.2 275 kV Line               0.0
# 10249  Tailem Bend - Tungkillo No.1 275 kV Line               0.0
# 10376  Tailem Bend - Tungkillo No.2 275 kV Line               0.0
# 10379  Tailem Bend - Tungkillo No.1 275 kV Line               0.0
#
#        Recall_Night_Hours  Project Work?  Unplanned?  DNSP Aware?  \
# 1005                  0.0              0           0            0
# 6824                  0.0              0           0            1
# 9039                  0.0              0           0            1
# 10109                 0.0              0           0            0
# 10110                 0.0              0           0            0
# 10246                 0.0              0           0            0
# 10249                 0.0              0           0            0
# 10376                 0.0              0           0            0
# 10379                 0.0              0           0            0
#
#        Generator Aware?  Inter-Regional Status_Description Status_Code  \
# 1005                  1               0                NaN         NaN
# 6824                  0               0            Planned      SUBMIT
# 9039                  1               0            Planned      SUBMIT
# 10109                 0               0                NaN         NaN
# 10110                 0               0                NaN         NaN
# 10246                 0               0                NaN         NaN
# 10249                 0               0                NaN         NaN
# 10376                 0               0                NaN         NaN
# 10379                 0               0                NaN         NaN
#
#       Status_Description_Market Market_Notice_Code Impact_Region  \
# 1005                    Planned              MTLTP           TAS
# 6824                    Planned           SUBMIT             QLD
# 9039                    Planned           SUBMIT             QLD
# 10109                   Planned           SUBMIT              SA
# 10110                   Planned           SUBMIT              SA
# 10246                   Planned              MTLTP            SA
# 10249                   Planned              MTLTP            SA
# 10376                   Planned              MTLTP            SA
# 10379                   Planned              MTLTP            SA
#
#               Reason  Duration_Hours  \
# 1005   Commissioning             NaN
# 6824   Commissioning             NaN
# 9039   Commissioning             NaN
# 10109    Maintenance             NaN
# 10110    Maintenance             NaN
# 10246    Maintenance             NaN
# 10249    Maintenance             NaN
# 10376    Maintenance             NaN
# 10379    Maintenance             NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Impact  \
# 1005                                                                                                                                                                                                                                                                                                                                                                                                          A credible contingency event during this planned outage could cause a large reduction in generation in Tasmania.
# 6824                                                                                                                                                                                                                                                                             <<NEW since the last notification>>  This is a high impact outage because the recall time is greater than 30 minutes.  A credible contingency event during this planned outage may require market intervention through issuing of directions.
# 9039                                                                                                                                                                                                                                                                                                                  This is a high impact outage because the recall time is greater than 30 minutes.  A credible contingency event during this planned outage may require market intervention through issuing of directions.
# 10109  A credible contingency event during this planned outage could leave South Australia connected to the NEM only via the South Australian 132 kV network. To maintain system security following this contingency AEMO will need to:   • Initiate the orderly separation of SA from the rest of the NEM.                 • Source increased local regulation FCAS within SA.    During this planned outage power transfer will be restricted across the Victoria - South Australia interconnector (Heywood interconnector).
# 10110  A credible contingency event during this planned outage could leave South Australia connected to the NEM only via the South Australian 132 kV network. To maintain system security following this contingency AEMO will need to:   • Initiate the orderly separation of SA from the rest of the NEM.                 • Source increased local regulation FCAS within SA.    During this planned outage power transfer will be restricted across the Victoria - South Australia interconnector (Heywood interconnector).
# 10246  A credible contingency event during this planned outage could leave South Australia connected to the NEM only via the South Australian 132 kV network. To maintain system security following this contingency AEMO will need to:    Initiate the orderly separation of SA from the rest of the NEM.                  Source increased local regulation FCAS within SA.    During this planned outage power transfer will be restricted across the Victoria - South Australia interconnector (Heywood interconnector).
# 10249  A credible contingency event during this planned outage could leave South Australia connected to the NEM only via the South Australian 132 kV network. To maintain system security following this contingency AEMO will need to:    Initiate the orderly separation of SA from the rest of the NEM.                  Source increased local regulation FCAS within SA.    During this planned outage power transfer will be restricted across the Victoria - South Australia interconnector (Heywood interconnector).
# 10376       A credible contingency event during this planned outage could leave South Australia connected to the NEM only via the South Australian 132 kV network. To maintain system security following this contingency AEMO will need to:  • Initiate the orderly separation of SA from the rest of the NEM.                • Source increased local regulation FCAS within SA.  During this planned outage power transfer will be restricted across the Victoria - South Australia interconnector (Heywood interconnector).
# 10379       A credible contingency event during this planned outage could leave South Australia connected to the NEM only via the South Australian 132 kV network. To maintain system security following this contingency AEMO will need to:  • Initiate the orderly separation of SA from the rest of the NEM.                • Source increased local regulation FCAS within SA.  During this planned outage power transfer will be restricted across the Victoria - South Australia interconnector (Heywood interconnector).
#
#         file_name
# 1005   2021-12-06
# 6824   2023-03-27
# 9039   2023-08-14
# 10109  2023-10-16
# 10110  2023-10-16
# 10246  2023-10-23
# 10249  2023-10-23
# 10376  2023-10-30
# 10379  2023-10-30
